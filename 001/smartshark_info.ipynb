# %% [markdown]
# # SmartSHARK Information
#
# SmartSHARK データの基本情報を調査する

# %% [markdown]
# ## Setup

# %%
import polars as pl

# %%
# 出力設定
pl.Config(tbl_rows=100)

# %% [markdown]
# ## Project 毎の情報

# %% [markdown]
# ### Commit
#
# | Column | Description |
# | --- | --- |
# | nc |  # of commits |
# | nbfc |  # of bug-fixing commits |
# | nbfc_a |  # of bug-fixing commits with adjustedszz |
# | nbfc_io |  # of bug-fixing commits with issueonly |
# | nbfc_v |  # of bug-fixing commits with validated |
# | nbfc_if |  # of bug-fixing commits with issuefasttext |
# | nbic |  # of bug-inducing commits |
# | nbic_szz |  # of bug-inducing commits with SZZ |
# | nbic_jl+r |  # of bug-inducing commits with JL+R |
# | nbic_jlip+r |  # of bug-inducing commits with JLIP+R |
# | nbic_jlmiv |  # of bug-inducing commits with JLMIV |
# | nbic_jlmiv+ |  # of bug-inducing commits with JLMIV+ |
# | nbic_jlmiv+av |  # of bug-inducing commits with JLMIV+AV |
# | nbic_jlmiv+rav |  # of bug-inducing commits with JLMIV+RAV |
# | nbic_jlmiv+r |  # of bug-inducing commits with JLMIV+R |

# %%
df = pl.read_csv("commit_info.csv")
display(df)
display(df.sum()[0, 1:])
# Out:
# shape: (98, 16)
# ┌──────────────┬───────┬──────┬────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ project      ┆ nc    ┆ nbfc ┆ nbfc_a ┆ … ┆ nbic_jlmiv+ ┆ nbic_jlmiv+ ┆ nbic_jlmiv+ ┆ nbic_jlmiv+ │
# │ ---          ┆ ---   ┆ ---  ┆ ---    ┆   ┆ ---         ┆ av          ┆ rav         ┆ r           │
# │ str          ┆ i64   ┆ i64  ┆ i64    ┆   ┆ i64         ┆ ---         ┆ ---         ┆ ---         │
# │              ┆       ┆      ┆        ┆   ┆             ┆ i64         ┆ i64         ┆ i64         │
# ╞══════════════╪═══════╪══════╪════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ commons-rdf  ┆ 1311  ┆ 64   ┆ 52     ┆ … ┆ 12          ┆ 12          ┆ 12          ┆ 12          │
# │ ant-ivy      ┆ 3189  ┆ 748  ┆ 722    ┆ … ┆ 383         ┆ 383         ┆ 358         ┆ 358         │
# │ commons-math ┆ 7222  ┆ 735  ┆ 468    ┆ … ┆ 349         ┆ 349         ┆ 340         ┆ 340         │
# ...

# %% [markdown]
# ### Pull Request
#
# | Column | Description |
# | --- | --- |
# | npr |  # of pull requests |
# | nmpr | # of merged pull requests |
# | nrpr | # of rejected pull requests |
# | nmpr_1c | # of merged pull requests with 1 commit |
# | nmpr_30c | # of merged pull requests with 30 or more commits |
# | nc_f | # of commits linked to a pull request and found in the SmartSAHRK database |
# | nc_nf | # of commits linked to a pull request but not found in the SmartSHARK database |
# | npr_cf | # of pull requests with commits found in the SmartSHARK database |
# | npr_cnf | # of pull requests with commits not found in the SmartSHARK database |
# | nbfpr |  # of bug-fixing pull requests |
# | nbfpr_a |  # of bug-fixing pull requests with adjustedszz |
# | nbfpr_io |  # of bug-fixing pull requests with issueonly |
# | nbfpr_v |  # of bug-fixing pull requests with validated |
# | nbfpr_if |  # of bug-fixing pull requests with issuefasttext |
# | nbipr |  # of bug-inducing pull requests |
# | nbipr_szz |  # of bug-inducing pull requests with SZZ |
# | nbipr_jl+r |  # of bug-inducing pull requests with JL+R |
# | nbipr_jlip+r |  # of bug-inducing pull requests with JLIP+R |
# | nbipr_jlmiv |  # of bug-inducing pull requests with JLMIV |
# | nbipr_jlmiv+ |  # of bug-inducing pull requests with JLMIV+ |
# | nbipr_jlmiv+av |  # of bug-inducing pull requests with JLMIV+AV |
# | nbipr_jlmiv+rav |  # of bug-inducing pull requests with JLMIV+RAV |
# | nbipr_jlmiv+r |  # of bug-inducing pull requests with JLMIV+R |

# %%
df = pl.read_csv("pull_request_info.csv")
display(df)
display(df.sum()[0, 1:])
# Out:
# shape: (98, 24)
# ┌──────────────┬──────┬──────┬──────┬───┬──────────────┬──────────────┬──────────────┬─────────────┐
# │ project      ┆ npr  ┆ nmpr ┆ nrpr ┆ … ┆ nbipr_jlmiv+ ┆ nbipr_jlmiv+ ┆ nbipr_jlmiv+ ┆ nbipr_jlmiv │
# │ ---          ┆ ---  ┆ ---  ┆ ---  ┆   ┆ ---          ┆ av           ┆ rav          ┆ +r          │
# │ str          ┆ i64  ┆ i64  ┆ i64  ┆   ┆ i64          ┆ ---          ┆ ---          ┆ ---         │
# │              ┆      ┆      ┆      ┆   ┆              ┆ i64          ┆ i64          ┆ i64         │
# ╞══════════════╪══════╪══════╪══════╪═══╪══════════════╪══════════════╪══════════════╪═════════════╡
# │ commons-rdf  ┆ 56   ┆ 37   ┆ 14   ┆ … ┆ 2            ┆ 2            ┆ 2            ┆ 2           │
# │ ant-ivy      ┆ 81   ┆ 28   ┆ 40   ┆ … ┆ 2            ┆ 2            ┆ 2            ┆ 2           │
# │ commons-math ┆ 160  ┆ 39   ┆ 65   ┆ … ┆ 2            ┆ 2            ┆ 2            ┆ 2           │
# ...
